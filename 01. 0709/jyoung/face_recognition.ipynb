# %%
pip install cmake
# Out:
# Requirement already satisfied: cmake in c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages (3.22.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)

# %%
pip install https://pypi.python.org/packages/da/06/bd3e241c4eb0a662914b3b4875fc52dd176a9db0d4a2c915ac2ad8800e9e/dlib-19.7.0-cp36-cp36m-win_amd64.whl#md5=b7330a5b2d46420343fbed5df69e6a3f

# %%
# pip install --upgrade pip

# %%
pip install face_recognition
# Out:
# Requirement already satisfied: face_recognition in c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages (1.3.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages)
# Requirement already satisfied: dlib>=19.7 in c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages (from face_recognition) (19.24.0)
# Requirement already satisfied: face-recognition-models>=0.3.0 in c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: numpy in c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages (from face_recognition) (1.21.3)
# Requirement already satisfied: Click>=6.0 in c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Pillow in c:\users\jooya\appdata\local\programs\python\python38\lib\site-packages (from face_recognition) (8.4.0)

# %%
import face_recognition

# %%
from PIL import Image

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file("56.jpg")

# Find all the faces in the image using the default HOG-based model.
# This method is fairly accurate, but not as accurate as the CNN model and not GPU accelerated.
# See also: find_faces_in_picture_cnn.py
face_locations = face_recognition.face_locations(image)

print("I found {} face(s) in this photograph.".format(len(face_locations)))

for face_location in face_locations:

    # Print the location of each face in this image
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # You can access the actual face itself like this:
    face_image = image[top:bottom, left:right]
    pil_image = Image.fromarray(face_image)
    pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 93, Left: 142, Bottom: 316, Right: 365

# %%
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=223x223 at 0x21AFDBCE280>
